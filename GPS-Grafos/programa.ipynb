# %%
from Dados import dados, grafo
import pandas as pd

# %%
grafo.Show_Vertices()
# Out:
# Vértice: Ituiutaba
# 	Ituiutaba --> Capinópolis: 30
# 	Ituiutaba --> Trevão: 40
# Vértice: Capinópolis
# 	Capinópolis --> Ituiutaba: 30
# Vértice: Trevão
# 	Trevão --> Ituiutaba: 40
# 	Trevão --> Prata: 70
# 	Trevão --> Monte Alegre: 20
# Vértice: Prata
# 	Prata --> Trevão: 70
# 	Prata --> Uberlândia: 70
# Vértice: Monte Alegre
# 	Monte Alegre --> Trevão: 20
# 	Monte Alegre --> Uberlândia: 60
# Vértice: Araguari
# 	Araguari --> Uberlândia: 30
# Vértice: Uberlândia
# 	Uberlândia --> Prata: 70
# 	Uberlândia --> Monte Alegre: 60
# 	Uberlândia --> Araguari: 30

# %%
dados = sorted(dados, key=lambda x: (x['Inicio'], x['Distancia']))
pd.DataFrame(dados)
# Out:
#           Inicio       Destino  Distancia
# 0       Araguari      Araguari          0
# 1       Araguari    Uberlândia         30
# 2       Araguari  Monte Alegre         90
# 3       Araguari         Prata        100
# 4       Araguari        Trevão        110
# 5       Araguari     Ituiutaba        150
# 6       Araguari   Capinópolis        180
# 7    Capinópolis   Capinópolis          0
# 8    Capinópolis     Ituiutaba         30
# 9    Capinópolis        Trevão         70
# 10   Capinópolis  Monte Alegre         90
# 11   Capinópolis         Prata        140
# 12   Capinópolis    Uberlândia        150
# 13   Capinópolis      Araguari        180
# 14     Ituiutaba     Ituiutaba          0
# 15     Ituiutaba   Capinópolis         30
# 16     Ituiutaba        Trevão         40
# 17     Ituiutaba  Monte Alegre         60
# 18     Ituiutaba         Prata        110
# 19     Ituiutaba    Uberlândia        120
# 20     Ituiutaba      Araguari        150
# ...
